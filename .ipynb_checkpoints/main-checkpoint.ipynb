# %%
import folium
import pickle
def load_path_graph(path):
    with open('graph.pkl', 'rb') as f:
        graph = pickle.load(f)


    node_pairs = list(zip(path[:-1], path[1:]))
    lines = []
    for edge in graph:
        if (edge['u'], edge['v']) in node_pairs or  (edge['v'], edge['u']) in node_pairs:
            lines.append(edge['geometry'])
    return lines

start = 2270143902; end = 1079387396
#start = 426882161; end = 1737223506
#start = 1718165260; end = 8513026827

# %%
import numpy as np
import pandas as pd
import threading
from multiprocessing import Process,Lock,Manager
from jobs import job

#global dist,accu_time,for_loop_time,sort_time,mid_time,nodes_query_time,edges_query_time,done,sort_time
#global edges, nodes, heuristics, visited, previous,distance,incumbent_cost

def foo():
    print("bar")





def astar(start = 2270143902, end = 1079387396):
    
    #global dist,accu_time,for_loop_time,sort_time,mid_time,nodes_query_time,edges_query_time,dist,done,sort_time
    #global edges, nodes, heuristics, visited, previous,distance,incumbent_cost
    
    edges = pd.read_csv('./edges.csv')
    edges.sort_values(by=['start'])
    edges_start_list = edges['start'].tolist()
    nodes = pd.DataFrame(edges)['start'].tolist() + pd.DataFrame(edges)['end'].tolist()
    edges.set_index(pd.Series(edges_start_list), inplace=True)
    edges.set_index('start', inplace=True)
    nodes = list(dict.fromkeys(nodes)) # remove duplicate
    nodes = pd.DataFrame(nodes,columns=['node'])
    nodes = nodes.set_index('node')
    nodes.sort_index(inplace = True)
    heuristics = pd.DataFrame(pd.read_csv('./heuristic.csv'),columns=['node', str(end)]).set_index('node')
    heuristics.sort_index(inplace = True)
    nodes['heuristics'] = heuristics[str(end)]
    visited = {}
    previous = {}
    distance = []

    nodes['visited'] = 0
    nodes['previous'] = -1
    nodes['g'] = 99999999999
    
    #print(" ===== edges table =====\n",edges)
    #print(" ===== nodes table =====\n",nodes)
    #print(" ===== heuristics table =====\n",heuristics)
    
    
    distance.append([start, 0, heuristics.at[start,str(end)], 0])
    nodes.at[str(start), 'visited'] = 1
    nodes.at[str(start), 'previous'] = -1
    num_visited = 0
    #global dist,accu_time,for_loop_time,sort_time,mid_time,nodes_query_time,edges_query_time,dist,done
    nodes_row,nodes_col = nodes.shape
    nodes_index = nodes.index
    #print("number of nodes: ",nodes_row)
    accu_time = 0.0
    for_loop_time = 0.0
    sort_time = 0.0
    mid_time = 0.0
    nodes_query_time = 0.0
    edges_query_time = 0.0
    dist = 0.0
    t_pool = []
    #manager = Manager() # Lock 的 manager
    lock1 = Lock()
    lock2 = Lock()
    incumbent_cost = 99999999999
    done = 0
    manager = Manager()
    ns = manager.Namespace()
    #start,end,dist,accu_time,for_loop_time,sort_time,mid_time,nodes_query_time,edges_query_time,done, edges, nodes, heuristics, visited, previous,distance,incumbent_cost
    ns.start = start
    ns.end = end
    ns.dist = dist
    ns.accu_time = accu_time
    ns.for_loop_time = for_loop_time
    ns.sort_time = sort_time
    ns.mid_time = mid_time
    ns.nodes_query_time = nodes_query_time
    ns.edges_query_time = edges_query_time 
    ns.edges = edges
    ns.nodes = nodes
    ns.heuristics = heuristics
    ns.visited = visited
    ns.previous = previous
    ns.distance = distance
    ns.incumbent_cost = incumbent_cost
    ns.done = done
    while not done:
        #print(done)
        if(len(distance) == 0):
            continue
        t_pool.append(Process(target = job,args=(ns,lock1,lock2)))
        #t_pool.append(threading.Thread(target = job,args=()))
        t_pool[-1].start()
        #job(start,end,dist,accu_time,for_loop_time,sort_time,mid_time,nodes_query_time,edges_query_time,done, edges, nodes, heuristics, visited, previous,distance,incumbent_cost)
    for i, t in enumerate(t_pool):
        t_pool[i].join()
    '''print("===== Performance =====")
    print("while loop time: ",t13 - t12)
    print("    sorting time", sort_time)
    print("    middle time", mid_time)
    print("      nodes query time", nodes_query_time)
    print("      edges query time", edges_query_time)
    print("    for loop time: ",for_loop_time)
    print("=======================")'''
    num_visited = nodes['visited'].sum() - 1
    path = []
    path.append(end)
    current_node = end
    t6 = time.time()
    nodes.at[start,'previous'] = -1
    while nodes.at[current_node,'previous'] != -1:
        path.append(nodes.at[current_node,'previous'])
        current_node = nodes.at[current_node,'previous']

    path.reverse()
    t7 = time.time()
    return path, dist, num_visited

# %%
# Don't change this part.
# Show the result of A* search
#global dist,accu_time,for_loop_time,sort_time,mid_time,nodes_query_time,edges_query_time,dist,done,sort_time
#global edges, nodes, heuristics, visited, previous

import time
st = time.time()
astar_path, astar_dist, astar_visited = astar(start, end)
en = time.time()

print(f'The number of nodes in the path found by A* search: {len(astar_path)}')
print(f'Total distance of path found by A* search: {astar_dist} m')
print(f'The number of visited nodes in A* search: {astar_visited}\n')
print("\nExecution time: ",en-st)

fmap = folium.Map(location=(24.806383132251874, 120.97685775516189), zoom_start=13)
for line in load_path_graph(astar_path):
    fmap.add_child(folium.PolyLine(locations=line, tooltip='astar', weight=4, color='red'))
fmap
# Out:
# job
# job
# Process Process-4:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-5:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-2:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-3:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# job
# job
# job
# Process Process-6:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-7:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-9:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-8:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# Process Process-10:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# Process Process-20:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-26:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# Process Process-11:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-25:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-21:
# Process Process-22:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-16:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-18:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-29:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-19:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# job
# job
# job
# job
# job
# job
# job
# job
# job
# Process Process-14:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-31:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-23:
# Process Process-17:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-12:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-28:
# Process Process-35:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# job
# Process Process-13:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# job
# job
# job
# job
# Process Process-15:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-33:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-27:
# Process Process-24:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-32:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-34:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-30:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# Process Process-38:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-37:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-36:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# Process Process-39:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-45:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# Process Process-49:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-47:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-40:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-43:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-51:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-50:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# Process Process-44:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-53:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-41:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-46:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# ...
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-56:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-60:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# job
# job
# job
# job
# job
# Process Process-71:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-69:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# job
# job
# Process Process-84:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-79:
# Process Process-70:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-92:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-76:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-74:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-78:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-72:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-88:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Process Process-73:
# Process Process-82:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
# job
# job
# job
# job
# job
# job
# job
# Process Process-77:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/chenyusheng/Desktop/平行程式設計/project/AI_HW2/jobs.py", line 40, in job
#     if(ns.nodes.at[e,'visited'] == 0):
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 1113, in __getattr__
#     return callmethod('__getattribute__', (key,))
#   File "/usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/multiprocessing/managers.py", line 825, in _callmethod
#     raise convert_to_error(kind, result)
# AttributeError: 'Namespace' object has no attribute 'nodes'
